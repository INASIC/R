# %% [markdown]
# # Introduction
#
# This exercise is about exploratory data analysis for multivariate datasets with a mix of numerical and nominal variables. The iris dataset is popular benchmark dataset that is available in R. It contains sepal lengths and widths and petal lengths and widths for three species of ﬂowers. You can load it with the command
#
# ```> data("iris")```
#
# and you can see the ﬁrst few rows of the dataset typing
#
#
# ```> head(iris)```
#
#
# The dataset contains 5 variables (columns). Which is the type of each variable? Compute mean and standard deviation, median and IQR for all numerical variables and the relative frequency table for any nominal variable (Hint: use the command table). Note that you can access the variables within a dataset either using iris$Sepal.Length (for example) or using the command attach(iris) to then access the variables names directly.
#
# Now represent the data graphically in a way that allows to explore both variable distributions as well as their relationships (explore the options of the plot, boxplot, and hist functions). Try also saving the graphics in your working directory in any image format (in RStudio you can use the Export option in the Plots window).
#
# Looking at the graphs you produced, which pair of variables you expect to be the one with higher correlation? Compute the empirical correlation matrix to check this.

# %% [markdown]
# # Load Dataset

# %%
data("iris")  # load data

# %% [markdown]
# ## Descriptive Statistics
#
# Calculate the mean, standard deviation, median, and IQR of the Iris features.

# %%
# Means
mean(iris$Sepal.Length)
mean(iris$Sepal.Width)
mean(iris$Petal.Length)
mean(iris$Petal.Width)
# Out:
# [1] 5.843333
# [1] 3.057333
# [1] 3.758
# [1] 1.199333

# %%
# Standard Deviations
sd(iris$Sepal.Length)
sd(iris$Sepal.Width)
sd(iris$Petal.Length)
sd(iris$Petal.Width)
# Out:
# [1] 0.8280661
# [1] 0.4358663
# [1] 1.765298
# [1] 0.7622377

# %%
# Medians
median(iris$Sepal.Length)
median(iris$Sepal.Width)
median(iris$Petal.Length)
median(iris$Petal.Width)
# Out:
# [1] 5.8
# [1] 3
# [1] 4.35
# [1] 1.3

# %%
# Interquartile Ranges
IQR(iris$Sepal.Length)
IQR(iris$Sepal.Width)
IQR(iris$Petal.Length)
IQR(iris$Petal.Width)
# Out:
# [1] 1.3
# [1] 0.5
# [1] 3.5
# [1] 1.5

# %% [markdown]
# # Exploratory Data Analysis (EDA)

# %%
head(iris)  # Peek at dataset
# Out:
#   Sepal.Length Sepal.Width Petal.Length Petal.Width Species
# 1 5.1          3.5         1.4          0.2         setosa
# 2 4.9          3.0         1.4          0.2         setosa
# 3 4.7          3.2         1.3          0.2         setosa
# 4 4.6          3.1         1.5          0.2         setosa
# 5 5.0          3.6         1.4          0.2         setosa
# 6 5.4          3.9         1.7          0.4         setosa

# %%
summary(iris)  # Descriptive statistics
# Out:
#   Sepal.Length    Sepal.Width     Petal.Length    Petal.Width
#  Min.   :4.300   Min.   :2.000   Min.   :1.000   Min.   :0.100
#  1st Qu.:5.100   1st Qu.:2.800   1st Qu.:1.600   1st Qu.:0.300
#  Median :5.800   Median :3.000   Median :4.350   Median :1.300
#  Mean   :5.843   Mean   :3.057   Mean   :3.758   Mean   :1.199
#  3rd Qu.:6.400   3rd Qu.:3.300   3rd Qu.:5.100   3rd Qu.:1.800
#  Max.   :7.900   Max.   :4.400   Max.   :6.900   Max.   :2.500
#        Species
#  setosa    :50
#  versicolor:50
#  virginica :50

# %%
sapply(iris, class)  # Datatypes
# Out:
# Sepal.Length  Sepal.Width Petal.Length  Petal.Width      Species
#    "numeric"    "numeric"    "numeric"    "numeric"     "factor"

# %% [markdown]
# Compare how the distributions of features vary for __different species__.

# %% [markdown]
# # Feature Distributions
#
# How to get transparent colours?

# %%
# Plot and compare matrix of histograms for the features of each of the species of iris
par(mfrow = c(2, 2))  # Dimensions for how the plots are displayed (2x2 matrix)

# Sepal Lengths
hist(iris$Sepal.Length[iris$Species=="setosa"], col='red', xlim=c(4,9), ylim=c(0,25), main='Sepal Length (cm)', xlab='')
hist(iris$Sepal.Length[iris$Species=="versicolor"], col='green', add=T)
hist(iris$Sepal.Length[iris$Species=="virginica"], col='blue', add=T)

# Sepal Widths
hist(iris$Sepal.Width[iris$Species=="setosa"], col='red', xlim=c(2,7), ylim=c(0,30), main='Sepal Width (cm)', ylab ='', xlab='')
hist(iris$Sepal.Width[iris$Species=="versicolor"], col='green', add=T)
hist(iris$Sepal.Width[iris$Species=="virginica"], col='blue', add=T)
legend("topright", c("Setosa", "Versicolor", "Virginica"), col=c("red", "green", "blue"), lwd=5)

# Petal Lengths
hist(iris$Petal.Length[iris$Species=="setosa"], col='red', xlim=c(0,8), ylim=c(0,25), main='Petal Length (cm)',xlab='')
hist(iris$Petal.Length[iris$Species=="versicolor"], col='green', add=T)
hist(iris$Petal.Length[iris$Species=="virginica"], col='blue', add=T)

# Petal Widths
hist(iris$Petal.Width[iris$Species=="setosa"], col='red', xlim=c(0,3), ylim=c(0,40), main='Petal Width (cm)', ylab='',xlab='')
hist(iris$Petal.Width[iris$Species=="versicolor"], col='green', add=T)
hist(iris$Petal.Width[iris$Species=="virginica"], col='blue', add=T)
# Out:
# Plot with title “Petal Width (cm)”

# %%
par(mfrow = c(2, 2))  # Dimensions for how the plots are displayed
colBoxPlot <- c("red","green","blue")  # Colours used for the boxplot
boxplot(data=iris, Sepal.Length ~ Species, main="Sepal Length (cm)", col=colBoxPlot)  # Create boxplot for sepal length for species
boxplot(data=iris, Sepal.Width ~ Species, main="Sepal Width (cm)", col=colBoxPlot)
boxplot(data=iris, Petal.Length ~ Species, main="Petal Length (cm)", col=colBoxPlot)
boxplot(data=iris, Petal.Width ~ Species, main="Petal Width (cm)", col=colBoxPlot)
# Out:
# Plot with title “Petal Width (cm)”

# %%
pairs(iris[1:4], col=iris$Species, main = "Iris Flowers")  # Pairplot of the features (scatterplot matrix)
# legend(iris$Species)
# Out:
# plot without title

# %% [markdown]
# # Further Work
#
# Note the matrix is symmetric. Perhaps plot __histograms along the diagonal__, and __Pearson correlation coefficients__ along the __opposite diagonal__?

# %% [markdown]
# $p = \frac{\sigma_{xy}}{\sigma_{xx} \sigma{yy}}$
